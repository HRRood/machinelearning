# %%
import pandas as pd

# %%
df = pd.read_csv(".\\data\\Salary_Data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  35 non-null     float64
#  1   Salary           35 non-null     float64
#  2   Age              35 non-null     int64
# dtypes: float64(2), int64(1)
# memory usage: 968.0 bytes

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# Age                0
# dtype: int64

# %%
df.head(10)
# Out:
#    YearsExperience   Salary  Age
# 0              1.1  39343.0   25
# 1              1.1  42000.0   25
# 2              1.3  40050.0   23
# 3              1.3  42000.0   23
# 4              1.5  37731.0   29
# 5              1.5  39275.0   29
# 6              2.0  43525.0   33
# 7              2.2  39891.0   30
# 8              2.2  41000.0   30
# 9              2.9  56642.0   35

# %%
df.tail()
# Out:
#     YearsExperience    Salary  Age
# 30              9.0  105582.0   55
# 31              9.5  116969.0   59
# 32              9.6  112635.0   59
# 33             10.3  122391.0   62
# 34             10.5  121872.0   63

# %%
df.corr()
# Out:
#                  YearsExperience    Salary       Age
# YearsExperience         1.000000  0.981444  0.976609
# Salary                  0.981444  1.000000  0.985639
# Age                     0.976609  0.985639  1.000000

# %%
X = df['YearsExperience'].values.reshape(-1,1)
y = df['Salary']

# %%
import matplotlib.pyplot as plt 

plt.scatter(X,y)
plt.xlabel('YeX')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2)

lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train, lr.predict(X_train))
plt.xlabel('YeX')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test, lr.predict(X_test))
plt.xlabel('YeX')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
lr.predict([[13]])
# Out:
# array([147382.79519439])

# %%
X = df[['YearsExperience','Age']]
y = df['Salary']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2)

lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[13,40]])
# Out:
# array([102122.87201932])

# %%
lr.score(X_train, y_train)
# Out:
# 0.9805393955039122

# %%
from sklearn.neighbors import KNeighborsClassifier

dfd = pd.read_csv(".\\data\\diabetes.csv")

# %%
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
X = dfd[['Pregnancies','Glucose', 'Age']]
y = dfd[['Outcome']]

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2)

# %%
kncl = KNeighborsClassifier(n_neighbors=3)

kncl.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
kncl.score(X_test,y_test)
# Out:
# 0.7207792207792207

# %%
kncl.predict([[2,160,32]])
# Out:
# array([1], dtype=int64)
